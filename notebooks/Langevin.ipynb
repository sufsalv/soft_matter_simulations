# %%
m = 1
sigma = 1 
epsilon = 1 
L = 20 * sigma
num_particles = 100
initial_positions = np.random.uniform(0,L)
T_values = np.linspace(0.1, 2.0, 5)
gamma = 1.0 
steps = 10000
dt = 0.01

# %%
def overdampedbrown(T):
    positions = np.zeros((N_particles, 2))
    for t in range(1, steps): 
        xi = np.random.normal(0, 1, size=2)
        positions = positions + np.sqrt(2 * k_B * T / (m * gamma)) * xi * np.sqrt(dt)
        positions = positions - np.floor(positions / L) * L
